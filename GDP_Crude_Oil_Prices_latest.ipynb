# %%
import pandas as pd #pandas library
import numpy as np  #numpy library
# %matplotlib inline 
import matplotlib.pyplot as plt #import matplotlib same as from maplotlib import pyplot as plt

# %%
#Load our external file
data = pd.read_excel('nigeria_gdp.xlsx',skiprows=7)
data_oil = pd.read_excel('crudeoil_prices.xlsx')

# %%
data.head()
#From the below dataset we need to drop irrelevant columns
# Out:
#   Unnamed: 0 GDP growth (annual %) GDP per capita growth (annual %)  \
# 0      Units                     %                                %
# 1       1960                   NaN                              NaN
# 2       1961              0.191795                         -1.82038
# 3       1962               4.10299                          1.96415
# 4       1963               8.57862                          6.31106
#
#   GDP (constant LCU) GDP per capita (constant LCU) GDP (current LCU)  \
# 0       constant LCU                  constant LCU       current LCU
# 1      8819015424300                        195380        2997268700
# 2      8835929898100                        191823        3190921200
# 3      9198467447000                        195591        3506715100
# 4      9987568915800                        207935        3689708800
#
#   GDP (current US$) GDP per capita (current US$)  \
# 0       current US$                  current US$
# 1       4.19609e+09                      92.9618
# 2        4.4672e+09                      96.9804
# 3        4.9093e+09                      104.389
# 4       5.16549e+09                      107.542
#
#   GDP, PPP (current international $)
# 0            current international $
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN

# %%
data.drop(columns = ['GDP (constant LCU)','GDP (current LCU)','GDP per capita (constant LCU)','GDP (current LCU)','GDP (current US$)','GDP, PPP (current international $)'], inplace = True)

# %%
data.head()
# Out:
#   Unnamed: 0 GDP growth (annual %) GDP per capita growth (annual %)  \
# 0      Units                     %                                %
# 1       1960                   NaN                              NaN
# 2       1961              0.191795                         -1.82038
# 3       1962               4.10299                          1.96415
# 4       1963               8.57862                          6.31106
#
#   GDP per capita (current US$)
# 0                  current US$
# 1                      92.9618
# 2                      96.9804
# 3                      104.389
# 4                      107.542

# %%
data.drop(0,axis = 0, inplace = True)  #drop row 0 since it contains column names

# %%
data.head()
# Out:
#   Unnamed: 0 GDP growth (annual %) GDP per capita growth (annual %)  \
# 1       1960                   NaN                              NaN
# 2       1961              0.191795                         -1.82038
# 3       1962               4.10299                          1.96415
# 4       1963               8.57862                          6.31106
# 5       1964               4.95049                           2.7392
#
#   GDP per capita (current US$)
# 1                      92.9618
# 2                      96.9804
# 3                      104.389
# 4                      107.542
# 5                       113.17

# %%
#rename the Unamed colum to Year
data = data.rename(columns= {'Unnamed: 0':'Years'})

# %%
data.head()
# Out:
#   Years GDP growth (annual %) GDP per capita growth (annual %)  \
# 1  1960                   NaN                              NaN
# 2  1961              0.191795                         -1.82038
# 3  1962               4.10299                          1.96415
# 4  1963               8.57862                          6.31106
# 5  1964               4.95049                           2.7392
#
#   GDP per capita (current US$)
# 1                      92.9618
# 2                      96.9804
# 3                      104.389
# 4                      107.542
# 5                       113.17

# %%
#what does our current data contain
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57 entries, 1 to 57
# Data columns (total 4 columns):
# Years                               57 non-null object
# GDP growth (annual %)               56 non-null object
# GDP per capita growth (annual %)    56 non-null object
# GDP per capita (current US$)        57 non-null object
# dtypes: object(4)
# memory usage: 2.2+ KB

# %%
data.isnull().head() #show the boolean value of NAN
# Out:
#    Years  GDP growth (annual %)  GDP per capita growth (annual %)  \
# 1  False                   True                              True
# 2  False                  False                             False
# 3  False                  False                             False
# 4  False                  False                             False
# 5  False                  False                             False
#
#    GDP per capita (current US$)
# 1                         False
# 2                         False
# 3                         False
# 4                         False
# 5                         False

# %%
#lets fill all NAN from "GDP growth (annual %)","GDP per capita growth (annual %)" to zero
#data.fillna(value = 0, inplace=True)

# %%
data.head()
# Out:
#   Years GDP growth (annual %) GDP per capita growth (annual %)  \
# 1  1960                   NaN                              NaN
# 2  1961              0.191795                         -1.82038
# 3  1962               4.10299                          1.96415
# 4  1963               8.57862                          6.31106
# 5  1964               4.95049                           2.7392
#
#   GDP per capita (current US$)
# 1                      92.9618
# 2                      96.9804
# 3                      104.389
# 4                      107.542
# 5                       113.17

# %%
data.dtypes
# Out:
# Years                               object
# GDP growth (annual %)               object
# GDP per capita growth (annual %)    object
# GDP per capita (current US$)        object
# dtype: object

# %%
data.dropna(inplace=True)

# %%
data.head()
# Out:
#   Years GDP growth (annual %) GDP per capita growth (annual %)  \
# 2  1961              0.191795                         -1.82038
# 3  1962               4.10299                          1.96415
# 4  1963               8.57862                          6.31106
# 5  1964               4.95049                           2.7392
# 6  1965               4.88498                          2.66464
#
#   GDP per capita (current US$)
# 2                      96.9804
# 3                      104.389
# 4                      107.542
# 5                       113.17
# 6                       117.19

# %%
#round up data to 2 decimal place
#Round up to 2 decimal places in other to get the naira and kobo equivalent.
#data = data.round(2)
data.head()
# Out:
#   Years GDP growth (annual %) GDP per capita growth (annual %)  \
# 2  1961              0.191795                         -1.82038
# 3  1962               4.10299                          1.96415
# 4  1963               8.57862                          6.31106
# 5  1964               4.95049                           2.7392
# 6  1965               4.88498                          2.66464
#
#   GDP per capita (current US$)
# 2                      96.9804
# 3                      104.389
# 4                      107.542
# 5                       113.17
# 6                       117.19

# %%
#data['GDP per capita (current US$)'].mean(),median() 
data.dtypes
# Out:
# Years                               object
# GDP growth (annual %)               object
# GDP per capita growth (annual %)    object
# GDP per capita (current US$)        object
# dtype: object

# %%
data.head()
# Out:
#   Years GDP growth (annual %) GDP per capita growth (annual %)  \
# 2  1961              0.191795                         -1.82038
# 3  1962               4.10299                          1.96415
# 4  1963               8.57862                          6.31106
# 5  1964               4.95049                           2.7392
# 6  1965               4.88498                          2.66464
#
#   GDP per capita (current US$)
# 2                      96.9804
# 3                      104.389
# 4                      107.542
# 5                       113.17
# 6                       117.19

# %%
data.dtypes #check datapes for each column
# Out:
# Years                               object
# GDP growth (annual %)               object
# GDP per capita growth (annual %)    object
# GDP per capita (current US$)        object
# dtype: object

# %%
#data['Years'] = pd.to_datetime(data['Years']) #convert generic year object to datetime object

# %%
data.dtypes
# Out:
# Years                               object
# GDP growth (annual %)               object
# GDP per capita growth (annual %)    object
# GDP per capita (current US$)        object
# dtype: object

# %%
data.tail()
# Out:
#    Years GDP growth (annual %) GDP per capita growth (annual %)  \
# 53  2012               4.27928                          1.52409
# 54  2013               5.39442                          2.61463
# 55  2014               6.30972                          3.51962
# 56  2015               2.65269                       -0.0222352
# 57  2016              -1.61687                         -4.16011
#
#    GDP per capita (current US$)
# 53                       2755.3
# 54                      2996.96
# 55                      3221.68
# 56                      2655.16
# 57                      2175.67

# %%
data.head()
# Out:
#   Years GDP growth (annual %) GDP per capita growth (annual %)  \
# 2  1961              0.191795                         -1.82038
# 3  1962               4.10299                          1.96415
# 4  1963               8.57862                          6.31106
# 5  1964               4.95049                           2.7392
# 6  1965               4.88498                          2.66464
#
#   GDP per capita (current US$)
# 2                      96.9804
# 3                      104.389
# 4                      107.542
# 5                       113.17
# 6                       117.19

# %%
data['GDP per capita (current US$)'] = pd.to_numeric(data['GDP per capita (current US$)']) #convert generic Gdp object to numeric object

# %%
data.dtypes
# Out:
# Years                                object
# GDP growth (annual %)                object
# GDP per capita growth (annual %)     object
# GDP per capita (current US$)        float64
# dtype: object

# %%
# def to_numeric(series):
#    return pd.to_numeric(series)

# data['GDP per capita (current US$)'] = to_numeric()
data['GDP per capita growth (annual %)'] = pd.to_numeric(data['GDP per capita growth (annual %)']) #convert generic Gdp object to numeric object

# %%
data.dtypes
# Out:
# Years                                object
# GDP growth (annual %)                object
# GDP per capita growth (annual %)    float64
# GDP per capita (current US$)        float64
# dtype: object

# %%
data['GDP growth (annual %)'] = pd.to_numeric(data['GDP growth (annual %)']) #convert generic Gdp object to numeric object

# %%
data.dtypes
# Out:
# Years                                object
# GDP growth (annual %)               float64
# GDP per capita growth (annual %)    float64
# GDP per capita (current US$)        float64
# dtype: object

# %%
data = data.round(2) #roun

# %%
data.head()
# Out:
#   Years  GDP growth (annual %)  GDP per capita growth (annual %)  \
# 2  1961                   0.19                             -1.82
# 3  1962                   4.10                              1.96
# 4  1963                   8.58                              6.31
# 5  1964                   4.95                              2.74
# 6  1965                   4.88                              2.66
#
#    GDP per capita (current US$)
# 2                         96.98
# 3                        104.39
# 4                        107.54
# 5                        113.17
# 6                        117.19

# %%
data.dtypes
# Out:
# Years                                object
# GDP growth (annual %)               float64
# GDP per capita growth (annual %)    float64
# GDP per capita (current US$)        float64
# dtype: object

# %%
data.Years = pd.to_datetime(data.Years).dt.to_period('Y')

# %%
data.head()
# Out:
#   Years  GDP growth (annual %)  GDP per capita growth (annual %)  \
# 2  1961                   0.19                             -1.82
# 3  1962                   4.10                              1.96
# 4  1963                   8.58                              6.31
# 5  1964                   4.95                              2.74
# 6  1965                   4.88                              2.66
#
#    GDP per capita (current US$)
# 2                         96.98
# 3                        104.39
# 4                        107.54
# 5                        113.17
# 6                        117.19

# %%
data.dtypes
# Out:
# Years                                object
# GDP growth (annual %)               float64
# GDP per capita growth (annual %)    float64
# GDP per capita (current US$)        float64
# dtype: object

# %%
#renamed colums to remove bracket, 
data.rename(columns = {'GDP growth (annual %)':'GDP growth','GDP per capita growth (annual %)':'GDP per capita growth','GDP per capita (current US$)':'GDP per capita'},inplace = True)
data.set_index('Years', inplace=True) #set index to 
data.head()
# Useful snippet for removing spaces in column
#cols = data.columns
# cols = cols.map(lambda x: x.replace(' ', '_') if isinstance(x, (str, unicode)) else x)
# df.columns = cols
# Out:
#        GDP growth  GDP per capita growth  GDP per capita
# Years
# 1961         0.19                  -1.82           96.98
# 1962         4.10                   1.96          104.39
# 1963         8.58                   6.31          107.54
# 1964         4.95                   2.74          113.17
# 1965         4.88                   2.66          117.19

# %%
data['GDP per capita'].plot(figsize=(20,10),linewidth=5, fontsize=20)
data['GDP per capita growth'].plot(figsize=(20,10),linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);
plt.ylabel('Currency in USD',fontsize=20);

#data.plot()
#plt.xlabel('Year', fontsize=20);

# plt.xticks(x, my_xticks)
# plt.yticks(np.arange(y.min(), y.max(), 50))
# plt.plot(x, y)
# plt.grid(axis='y', linestyle='-')
#plt.show()

# %%
data_oil.dtypes
# Out:
# Date                              object
# Price in Contemporary Dollars    float64
# Unnamed: 2                       float64
# Growth rate                      float64
# dtype: object

# %%
data_oil.head()
# Out:
#          Date  Price in Contemporary Dollars  Unnamed: 2  Growth rate
# 0  12/31/2016                      43.734170    0.000000     0.000000
# 1  12/31/2015                      52.386759   -0.165167   -16.516748
# 2  12/31/2014                      98.946008   -0.470552   -47.055207
# 3  12/31/2013                     108.658518   -0.089386    -8.938563
# 4  12/31/2012                     111.669702   -0.026965    -2.696510

# %%
data_oil.drop(columns = 'Unnamed: 2', axis=1, inplace = True)  #drop Unamed Column

# %%
#data_oil['Date']  #convert generic object to datetime object and pick only the year
data_oil['Date'] = pd.to_datetime(data_oil['Date']).dt.year;
data_oil.head()
# Out:
#    Date  Price in Contemporary Dollars  Growth rate
# 0  2016                      43.734170     0.000000
# 1  2015                      52.386759   -16.516748
# 2  2014                      98.946008   -47.055207
# 3  2013                     108.658518    -8.938563
# 4  2012                     111.669702    -2.696510

# %%
#lets filter our dataset to include only year > 1960
data_oil = data_oil[data_oil['Date'] > 1960]

# %%
data_oil.columns[0]
# Out:
# 'Date'

# %%
#data_oil = data_oil.sort_values(data_oil.columns[0])
#data_oil = data_oil.round(2) #round up data to 2 decimal places
data_oil = data_oil.reset_index(drop=True) #reset index
#data_oil
data_oil[:10] #lets slice this baby select 0-9
# Out:
#    Date  Price in Contemporary Dollars  Growth rate
# 0  2016                      43.734170     0.000000
# 1  2015                      52.386759   -16.516748
# 2  2014                      98.946008   -47.055207
# 3  2013                     108.658518    -8.938563
# 4  2012                     111.669702    -2.696510
# 5  2011                     111.255598     0.372210
# 6  2010                      79.495534    39.952011
# 7  2009                      61.671265    28.902065
# 8  2008                      97.255973   -36.588712
# 9  2007                      72.389078    34.351721

# %%
# Use .apply() to apply a custom function to the weekdays column
#df['d'],df['rowIndex'] = df['a'] + df['b'] * df['c'], df.index
#I was rying to form Bill gate here o
#data_oil['index'] = range(1,57)
#data_oil['Price in Contemporary Dollars'].iloc[[0]]=0
#data_oil.iloc[56] = 0
#data_oil.head()
#((B2/B3) - 1)*100

# %%
#oil_prices = data_oil['Price in Contemporary Dollars']
#data_oil['index']
#growth_rate = lambda x: (oil_prices[x]/oil_prices[x])*100
#data_oil['result'] = data_oil['index'].apply(growth_rate)

# %%
oil_prices = data_oil['Price in Contemporary Dollars']
oil_growth = data_oil['Growth rate']

# %%
#dataet for oil prices
data_oil.head()
# Out:
#    Date  Price in Contemporary Dollars  Growth rate
# 0  2016                      43.734170     0.000000
# 1  2015                      52.386759   -16.516748
# 2  2014                      98.946008   -47.055207
# 3  2013                     108.658518    -8.938563
# 4  2012                     111.669702    -2.696510

# %%
#dataet for oil prices
data_oil.set_index('Date', inplace=True) #set index to 
data.head()
# Out:
#        GDP growth  GDP per capita growth  GDP per capita
# Years
# 1961         0.19                  -1.82           96.98
# 1962         4.10                   1.96          104.39
# 1963         8.58                   6.31          107.54
# 1964         4.95                   2.74          113.17
# 1965         4.88                   2.66          117.19

# %%
oil_prices = data_oil['Price in Contemporary Dollars']
oil_growth = data_oil['Growth rate']

# %%
#merge the oilprices dataset with gdp dataset
# assign() it to our dataframe
data = data.assign(oil_prices=oil_prices,oil_growth=oil_growth) #we can also use this but is the below one  easier to type?Idk
#data['oil_prices'] = oil_prices
#data['oil_growth'] = oil_growth
#oil_prices.head()
#data = data.assign(oil_prices=oil_prices)
#data['GDP growth'] = data['GDP growth']*100

# %%
data.tail()
# Out:
#        GDP growth  GDP per capita growth  GDP per capita  oil_prices  \
# Years
# 2012         4.28                   1.52         2755.30         NaN
# 2013         5.39                   2.61         2996.96         NaN
# 2014         6.31                   3.52         3221.68         NaN
# 2015         2.65                  -0.02         2655.16         NaN
# 2016        -1.62                  -4.16         2175.67         NaN
#
#        oil_growth
# Years
# 2012          NaN
# 2013          NaN
# 2014          NaN
# 2015          NaN
# 2016          NaN

# %%
data = data.loc['1996':'2017']

data
# Out:
#        GDP growth  GDP per capita growth  GDP per capita  oil_prices  \
# Years
# 1996         4.99                   2.41          315.97         NaN
# 1997         2.80                   0.28          315.55         NaN
# 1998         2.72                   0.19          274.99         NaN
# 1999         0.47                  -2.00          300.61         NaN
# 2000         5.32                   2.71          379.12         NaN
# 2001         4.41                   1.82          351.80         NaN
# 2002         3.78                   1.20          459.46         NaN
# 2003        10.35                   7.59          512.65         NaN
# 2004        33.74                  30.36          648.82         NaN
# 2005         3.44                   0.80          807.89         NaN
# 2006         8.21                   5.42         1019.74         NaN
# 2007         6.83                   4.05         1136.83         NaN
# 2008         6.27                   3.49         1383.89         NaN
# 2009         6.93                   4.13         1097.66         NaN
# 2010         7.84                   5.00         2327.32         NaN
# 2011         4.89                   2.12         2527.94         NaN
# 2012         4.28                   1.52         2755.30         NaN
# 2013         5.39                   2.61         2996.96         NaN
# 2014         6.31                   3.52         3221.68         NaN
# 2015         2.65                  -0.02         2655.16         NaN
# 2016        -1.62                  -4.16         2175.67         NaN
#
#        oil_growth
# Years
# 1996          NaN
# 1997          NaN
# 1998          NaN
# 1999          NaN
# 2000          NaN
# 2001          NaN
# 2002          NaN
# 2003          NaN
# 2004          NaN
# 2005          NaN
# 2006          NaN
# 2007          NaN
# 2008          NaN
# 2009          NaN
# 2010          NaN
# 2011          NaN
# 2012          NaN
# 2013          NaN
# 2014          NaN
# 2015          NaN
# 2016          NaN

# %%
#data.index = data.index.astype(int)
data['oil_growth'].plot(figsize=(30,20),linewidth=5, fontsize=20 )#
data['GDP growth'].plot(figsize=(30,20),linewidth=5, fontsize=20)#
plt.title('GDP % growth rate vs Crude Oil % growth rate',fontsize = 20)
#plt.plot(data.oil_prices,)
#data[['GDP per capita growth']].plot(figsize=(20,10),linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);
plt.ylabel('Growth Rate',fontsize=20);
plt.legend(['Crude Oil Growth', 'GDP Growth'])

# %%
data[['oil_growth']].plot(figsize=(20,10),linewidth=5, fontsize=20 )#

# %%
data[['GDP growth']].plot(figsize=(20,10),linewidth=5, fontsize=20 )#

# %%
#data.iin[['Year']>'1995']

# %%
# data to plot
n_groups = len(data.index)
oil_growth =  data['oil_growth']
gdp_growth = data['GDP growth']
# data['oil_growth'].plot(figsize=(20,10),linewidth=5, fontsize=20 )#
#data['GDP growth'].plot(figsize=(20,10),linewidth=5, fontsize=20)#
# create plot

fig, ax = plt.subplots(figsize=(20,10),linewidth=5)
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8
#plt.figsize = (50,40)
rects1 = plt.bar(index, oil_growth, bar_width,
                 alpha=opacity,
                 color='b',
                 label='Oil Growth')
 
rects2 = plt.bar(index + bar_width, gdp_growth, bar_width,
                 alpha=opacity,
                 color='g',
                 label='GDP Growth')
 
plt.xlabel('Growth Percentage')
plt.ylabel('Years')
plt.title('Comparison Between Oil Growth and Gdp Growth')
plt.xticks(index + bar_width, (data.index))
plt.legend()
 
plt.tight_layout()
plt.show()

# %%
#import population growth and unemployment rate dataset
data_population = pd.read_excel('populationgrowth_rate.xlsx')
data_unemployment = pd.read_excel('unemployment_rate.xlsx')

# %%
data_population#population growth
# Out:
#     Year  Rate
# 0   2000  2.67
# 1   2001  2.61
# 2   2002  2.54
# 3   2003  2.53
# 4   2004  2.45
# 5   2005  2.37
# 6   2006  2.38
# 7   2007  2.38
# 8   2008  2.03
# 9   2009  2.00
# 10  2010  1.97
# 11  2011  1.94
# 12  2012  2.55
# 13  2013  2.54
# 14  2014  2.47
# 15  2015  2.44
# 16  2016  2.44

# %%
#lets set the population index to Year
data_population.set_index('Year', inplace=True) 
data_population.head()
#data_population.set_index()
# Out:
#       Rate
# Year
# 2000  2.67
# 2001  2.61
# 2002  2.54
# 2003  2.53
# 2004  2.45

# %%
#data_unemployment #unemployment rate
#lets set the population index to Year
data_unemployment.set_index('Year', inplace=True) 
data_unemployment.head()
# Out:
#       Growth
# Year
# 2016    13.4
# 2015     9.0
# 2014     7.8
# 2013    10.0
# 2012    10.6

# %%
data.tail()
# Out:
#        GDP growth  GDP per capita growth  GDP per capita  oil_prices  \
# Years
# 2012         4.28                   1.52         2755.30  111.669702
# 2013         5.39                   2.61         2996.96  108.658518
# 2014         6.31                   3.52         3221.68   98.946008
# 2015         2.65                  -0.02         2655.16   52.386759
# 2016        -1.62                  -4.16         2175.67   43.734170
#
#        oil_growth
# Years
# 2012    -2.696510
# 2013    -8.938563
# 2014   -47.055207
# 2015   -16.516748
# 2016     0.000000

# %%
#to plot population and gdp lets filter any year thats less than 2000
data = data.loc['2000':'2016']

# %%
data.head()
# Out:
#        GDP growth  GDP per capita growth  GDP per capita  oil_prices  \
# Years
# 2000         5.32                   2.71          379.12   28.495449
# 2001         4.41                   1.82          351.80   24.443891
# 2002         3.78                   1.20          459.46   25.023256
# 2003        10.35                   7.59          512.65   28.830703
# 2004        33.74                  30.36          648.82   38.265000
#
#        oil_growth
# Years
# 2000   -14.218264
# 2001     2.370182
# 2002    15.215635
# 2003    32.723090
# 2004    42.482920

# %%
#data_population.head()
data_all =data.assign(population_growth = data_population) #contains all growth
data_all.fillna(0)
data_as_pol = data.assign(population_growth = data_population)#contains all population growth

# %%
data_as_pol
# Out:
#        GDP growth  GDP per capita growth  GDP per capita  oil_prices  \
# Years
# 2000         5.32                   2.71          379.12   28.495449
# 2001         4.41                   1.82          351.80   24.443891
# 2002         3.78                   1.20          459.46   25.023256
# 2003        10.35                   7.59          512.65   28.830703
# 2004        33.74                  30.36          648.82   38.265000
# 2005         3.44                   0.80          807.89   54.521089
# 2006         8.21                   5.42         1019.74   65.144063
# 2007         6.83                   4.05         1136.83   72.389078
# 2008         6.27                   3.49         1383.89   97.255973
# 2009         6.93                   4.13         1097.66   61.671265
# 2010         7.84                   5.00         2327.32   79.495534
# 2011         4.89                   2.12         2527.94  111.255598
# 2012         4.28                   1.52         2755.30  111.669702
# 2013         5.39                   2.61         2996.96  108.658518
# 2014         6.31                   3.52         3221.68   98.946008
# 2015         2.65                  -0.02         2655.16   52.386759
# 2016        -1.62                  -4.16         2175.67   43.734170
#
#        oil_growth  population_growth
# Years
# 2000   -14.218264               2.67
# 2001     2.370182               2.61
# 2002    15.215635               2.54
# 2003    32.723090               2.53
# 2004    42.482920               2.45
# 2005    19.484154               2.37
# 2006    11.121529               2.38
# 2007    34.351721               2.38
# 2008   -36.588712               2.03
# 2009    28.902065               2.00
# 2010    39.952011               1.97
# 2011     0.372210               1.94
# 2012    -2.696510               2.55
# 2013    -8.938563               2.54
# 2014   -47.055207               2.47
# 2015   -16.516748               2.44
# 2016     0.000000               2.44

# %%
#make we plot our graph for population and gdp
data_as_pol['population_growth'].plot(figsize=(30,20),linewidth=5, fontsize=20 )#
data_as_pol['GDP growth'].plot(figsize=(30,20),linewidth=5, fontsize=20)#
plt.title('GDP % growth rate vs Population % growth rate',fontsize = 20)
#plt.plot(data.oil_prices,)
#data[['GDP per capita growth']].plot(figsize=(20,10),linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);
plt.ylabel('Growth Rate',fontsize=20);
plt.legend(['Population Growth', 'Gdp Growth'],fontsize=20)

# %%
data = data.loc['2010':'2016']
data_as_une = data.assign(unemployment_growth = data_unemployment)#contains all population growth

# %%
data_as_une #unemployment data
# Out:
#        GDP growth  GDP per capita growth  GDP per capita  oil_prices  \
# Years
# 2010         7.84                   5.00         2327.32   79.495534
# 2011         4.89                   2.12         2527.94  111.255598
# 2012         4.28                   1.52         2755.30  111.669702
# 2013         5.39                   2.61         2996.96  108.658518
# 2014         6.31                   3.52         3221.68   98.946008
# 2015         2.65                  -0.02         2655.16   52.386759
# 2016        -1.62                  -4.16         2175.67   43.734170
#
#        oil_growth  unemployment_growth
# Years
# 2010    39.952011                  5.1
# 2011     0.372210                  6.0
# 2012    -2.696510                 10.6
# 2013    -8.938563                 10.0
# 2014   -47.055207                  7.8
# 2015   -16.516748                  9.0
# 2016     0.000000                 13.4

# %%
#make we plot our graph for population and gdp
data_as_une['unemployment_growth'].plot(figsize=(30,20),linewidth=5, fontsize=20 )#
data_as_une['GDP growth'].plot(figsize=(30,20),linewidth=5, fontsize=20)#
plt.title('GDP % growth rate vs Unemployment % growth rate',fontsize = 20)
#plt.plot(data.oil_prices,)
#data[['GDP per capita growth']].plot(figsize=(20,10),linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);
plt.ylabel('Growth Rate',fontsize=20);
plt.legend(['Unemployment Growth', 'Gdp Growth'],fontsize= 20)
